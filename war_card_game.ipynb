# %%
suits = ['hearts', 'spades', 'diamonds', 'clubs']

ranks = ['two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine', 'ten', 'jack', 'queen', 'king', 'ace']

#values = dict ( zip ( ranks, range (2,15)))

values = {'two': 2, 'three': 3, 'four': 4, 'five': 5, 'six': 6, 'seven': 7, 'eight': 8, 'nine': 9, 'ten': 10, 'jack': 11, 'queen': 12, 'king': 13, 'ace': 14}

# %%
class Card ():
    
    def __init__(self, suit, rank):
        
        self.suit = suit
        self.rank = rank
        self.value = values [rank]
    
    def __str__(self):
        
        return f'{self.rank} of {self.suit}'

# %%
from random import shuffle
    
class Deck ():
    
    def __init__(self):
        
        self.all = [Card (s, r) for s in suits for r in ranks]
    
    def __len__(self):
        
        return len(self.all)
    
    def __str__(self):
        
        [print(c) for c in self.all]
    
    def deal_one (self):
        
        return self.all.pop()
    
    def add_one (self, card):
        
        if type(card) == str :
            self.all.append (card)
        elif type(card) == list:
            self.all.extend (card)
    
    def shuffle (self):
        
        shuffle(self.all)

# %%
class Player():
    
    def __init__(self, name):
        
        self.name = name
        
        self.all = []
        
    def __str__(self):
        
        return f'{self.name} has {len(self.all)} cards'
    
    def __len__(self):
        
        return len(self.all)
    
    def deal_one (self):
        
        return self.all.pop(0)
    
    def add_card (self, card):
        
        if type(card) != list:
            
            self.all.append (card)
        
        elif type(card) == list:
            
            self.all.extend (card)

# %%
def war_game():
    
    d1 = Deck()

    d1.shuffle()

    p1 = Player('Alice')

    p2 = Player('Baker')

    for n in range (26):

        p1.add_card(d1.deal_one())
        p2.add_card(d1.deal_one())

    counter = 0

    while True:

        counter += 1
        
        if len(p1) <= 5:
            print (f'{p1.name} has <= 5 cards; {p2.name} won')
            break
            
        elif len(p2) <= 5:
            print (f'{p2.name} has <= 5 cards; {p1.name} won')
            break
        
        else:
            pass

        pool = []

        p1_card = p1.deal_one()

        p2_card = p2.deal_one()

        pool.extend ([p1_card, p2_card])

        if p1_card.value > p2_card.value:
            p1.add_card(pool)
            print (f'{p1.name} has {p1_card}; {p2.name} has {p2_card}')
            print (f'{p1.name} won round {counter}')
            print (f'{p1.name} has {len(p1)} cards')
            print (f'{p2.name} has {len(p2)} cards')

        elif p1_card.value < p2_card.value:
            p2.add_card(pool)
            print (f'{p1.name} has {p1_card}; {p2.name} has {p2_card}')
            print (f'{p2.name} won round {counter}')
            print (f'{p1.name} has {len(p1)} cards')
            print (f'{p2.name} has {len(p2)} cards')
            

        elif p1_card.value == p2_card.value:

            print (f'war at round {counter}')

            while True:

                for n in range (4):
                    p1_card = p1.deal_one()
                    p2_card = p2.deal_one()
                    pool.extend ([p1_card, p2_card])

                if p1_card.value > p2_card.value:
                    p1.add_card(pool)
                    print (f'{p1.name} has {p1_card}; {p2.name} has {p2_card}')
                    print (f'{p1.name} won war at round {counter}')
                    print (f'{p1.name} has {len(p1)} cards')
                    print (f'{p2.name} has {len(p2)} cards')
                    break

                elif p1_card.value < p2_card.value:
                    p2.add_card(pool)
                    print (f'{p1.name} has {p1_card}; {p2.name} has {p2_card}')
                    print (f'{p2.name} won war round {counter}')
                    print (f'{p1.name} has {len(p1)} cards')
                    print (f'{p2.name} has {len(p2)} cards')
                    break

                else:
                    continue

        if counter == 20:
            break

# %%
war_game()
# Out:
# Alice has eight of hearts; Baker has seven of hearts
# Alice won round 1
# Alice has 27 cards
# Baker has 25 cards
# Alice has king of diamonds; Baker has four of spades
# Alice won round 2
# Alice has 28 cards
# Baker has 24 cards
# Alice has six of clubs; Baker has ten of spades
# Baker won round 3
# Alice has 27 cards
# Baker has 25 cards
# Alice has jack of spades; Baker has six of diamonds
# Alice won round 4
# Alice has 28 cards
# Baker has 24 cards
# Alice has seven of diamonds; Baker has jack of clubs
# Baker won round 5
# Alice has 27 cards
# Baker has 25 cards
# Alice has nine of diamonds; Baker has four of hearts
# Alice won round 6
# Alice has 28 cards
# Baker has 24 cards
# Alice has six of hearts; Baker has jack of hearts
# Baker won round 7
# Alice has 27 cards
# Baker has 25 cards
# Alice has nine of hearts; Baker has four of clubs
# Alice won round 8
# Alice has 28 cards
# Baker has 24 cards
# Alice has queen of spades; Baker has king of hearts
# Baker won round 9
# Alice has 27 cards
# Baker has 25 cards
# Alice has ace of hearts; Baker has queen of hearts
# Alice won round 10
# Alice has 28 cards
# Baker has 24 cards
# war at round 11
# Alice has ten of hearts; Baker has ace of spades
# Baker won war round 11
# Alice has 23 cards
# Baker has 29 cards
# Alice has nine of clubs; Baker has jack of diamonds
# Baker won round 12
# Alice has 22 cards
# Baker has 30 cards
# Alice has seven of spades; Baker has queen of diamonds
# Baker won round 13
# Alice has 21 cards
# Baker has 31 cards
# Alice has queen of clubs; Baker has three of spades
# Alice won round 14
# Alice has 22 cards
# Baker has 30 cards
# Alice has ace of clubs; Baker has three of diamonds
# Alice won round 15
# Alice has 23 cards
# Baker has 29 cards
# war at round 16
# Alice has ten of clubs; Baker has eight of diamonds
# Alice won war at round 16
# Alice has 28 cards
# Baker has 24 cards
# Alice has nine of spades; Baker has king of spades
# Baker won round 17
# Alice has 27 cards
# Baker has 25 cards
# Alice has two of spades; Baker has king of clubs
# Baker won round 18
# Alice has 26 cards
# Baker has 26 cards
# Alice has eight of hearts; Baker has six of clubs
# Alice won round 19
# Alice has 27 cards
# Baker has 25 cards
# Alice has seven of hearts; Baker has ten of spades
# Baker won round 20
# Alice has 26 cards
# Baker has 26 cards
